# %% [markdown]
# # Combined Rare Disease data.tsv
#
# - preprocess each dataset (as done in individual GTRx and OOPD benchmarks), loosely following [get_indications.py](https://github.com/TranslatorSRI/Benchmarks/blob/main/config/DrugCentral_creative/get_indications.py)
# - combine with only ids and names

# %%
import pandas as pd
import requests
from biothings_client import get_client

# %% [markdown]
# ## OOPD

# %%
mc = get_client('chem')
oopd = mc.query(
        '_exists_:fda_orphan_drug', 
        fields='fda_orphan_drug',
        fetch_all=True)

# %%
df_oopd = pd.DataFrame(columns=['_id', 'drug_pubchem_cid', 'disease_umls', 'drug_name', 'disease_name', 'status', 'date'])

for drug in oopd:
    
    _id = drug['_id']
    
    # orphan designation 
    for use in drug['fda_orphan_drug']:

        # designation status/approval (may be useful for filtering)
        status = use['designation_status']
        date = use['designated_date']
            

        if isinstance(use['orphan_designation']['umls'], list):
            names = use['orphan_designation']['parsed_text']
            umls = use['orphan_designation']['umls']
        else:
            names = [use['orphan_designation']['parsed_text']]
            umls = [use['orphan_designation']['umls']]
        # for now, skip if there are nested lists of names
        if any(isinstance(el, list) for el in names):
            continue
        name_uml_dict = dict(zip(names, umls))
        
        if 'pubchem_cid' in use.keys():
            if isinstance(use['pubchem_cid'], list):
                continue
            cid = 'PUBCHEM.COMPOUND:' + str(use['pubchem_cid'])
        else:
            cid = ''
            # only include cases where a pubchem cid exists (used for querying)
            continue

        for name, uml in name_uml_dict.items():
            disease_umls = "UMLS:" + uml
            disease_name = name
            new_record = {
                '_id': _id,
                'drug_name': use['generic_name'],
                'drug_pubchem_cid': cid,
                'disease_umls': disease_umls,
                'disease_name': disease_name,
                'status': status,
                'date': date
                }
            #print(new_record)
            df_oopd.loc[len(df_oopd)] = new_record
# Out:
# INFO:biothings.client:Fetching 3661 chem(s) . . .
# ERROR:biothings.client:No more results to return.

# %%
df_oopd = df_oopd.sort_values('_id')

# restrict to only 1 drug per disease
df_oopd = df_oopd.drop_duplicates('disease_umls', keep=False)

# keep only those drugs whose use is approved
df_oopd = df_oopd.loc[df_oopd['status'] == 'Designated/Approved']

df_oopd = df_oopd.drop(columns=['status', 'date'])
df_oopd.rename(columns={'drug_pubchem_cid': 'drug_id', 'disease_umls': 'disease_id'}, inplace=True)
df_oopd
# Out:
#                               _id                     drug_id     disease_id  \
# 2070  ACTRVOBWPAIOHC-XIXRPRMCSA-N    PUBCHEM.COMPOUND:2724354  UMLS:C0149921
# 1927  APKFDSVGJQXUKY-INPOYWNPSA-N    PUBCHEM.COMPOUND:5280965  UMLS:C0085436
# 628   APKFDSVGJQXUKY-VTPNKFOWSA-N  PUBCHEM.COMPOUND:118705500  UMLS:C1262313
# 1229  AQHHHDLHHXJYJD-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4946  UMLS:C0018916
# 49    AUFUWRKPQLGTGF-FMKGYKFTSA-N      PUBCHEM.COMPOUND:20058  UMLS:C0268130
# ...                           ...                         ...            ...
# 1289  YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596  UMLS:C0346421
# 3637  YQNQNVDNTFHQSW-UHFFFAOYSA-N      PUBCHEM.COMPOUND:41684  UMLS:C0010418
# 3029  ZDXPYRJPNDTMRX-VKHMYHEASA-N       PUBCHEM.COMPOUND:5961  UMLS:C0024523
# 1903  ZHSKUOZOLHMKEA-UHFFFAOYSA-N      PUBCHEM.COMPOUND:77082  UMLS:C1955690
# 1902  ZHSKUOZOLHMKEA-UHFFFAOYSA-N      PUBCHEM.COMPOUND:77082  UMLS:C0855139
#
#                          drug_name                              disease_name
# 2070                      Succimer                lead poisoning in children
# 1927      Liposomal amphotericin B                   Cryptococcal meningitis
# 628   Amphotericin B lipid complex                Invasive Fungal Infections
# 1229                   propranolol                               Hemangiomas
# 49              uridine triacetate                           OROTIC ACIDURIA
# ...                            ...                                       ...
# 1289             Imatinib mesylate             Chronic eosinophilic leukemia
# 3637                  Nitazoxanide                         Cryptosporidiosis
# 3029                     Glutamine                             Malabsorption
# 1903    bendamustine hydrochloride  Extranodal marginal zone B-cell lymphoma
# 1902    bendamustine hydrochloride              Nodal Marginal Zone Lymphoma
#
# [85 rows x 5 columns]

# %% [markdown]
# ## GTRx

# %%
url = 'https://biothings.ncats.io/gtrx/query?q=predicate:treated_by&fetch_all=True'
data = requests.get(url)
gtrx = data.json()
gtrx = gtrx['hits']

# %%
df_gtrx = pd.DataFrame(columns=['_id', 'drug_inxight', 'disease_omim', 'drug_name', 'disease_name', 'nref'])

for entry in gtrx:
    # association id
    _id = entry['_id']
    
    # drug info
    # if a drug intervention has multiple entries -> combination therapy, all drug names/ids hyphenated
    drug_name = ''
    drug_inxight = ''
    for drug in entry['object']['intervention']:
        drug_name += (drug['description'] + '-')
        drug_inxight += ('UNII:' + drug['inxight'] + '-')
        
    drug_name = drug_name[:-1]
    drug_inxight = drug_inxight[:-1]
    
    # disease info
    disease_name = entry['subject']['condition_name']
    #disease_name = ','.join(entry['subject']['alternate_names'])
    disease_omim = 'OMIM:' + entry['subject']['omim']
    
    # number of references
    nref = len(entry['references'])
    
    new_record = {
        '_id': _id,
        'drug_name': drug_name,
        'drug_inxight': drug_inxight,
        'disease_name': disease_name,
        'disease_omim': disease_omim,
        'nref': nref
    }
    df_gtrx.loc[len(df_gtrx)] = new_record

# %%
# remove interventions with multiple drugs
df_gtrx = df_gtrx[~df_gtrx['drug_inxight'].str.contains('-')]

# restrict to only 1 drug per disease
df_gtrx = df_gtrx.drop_duplicates('disease_omim', keep=False)

df_gtrx = df_gtrx.drop(columns=['nref'])
df_gtrx.rename(columns={'drug_inxight': 'drug_id', 'disease_omim': 'disease_id'}, inplace=True)
df_gtrx
# Out:
#                               _id          drug_id   disease_id  \
# 4     1037-OMIM:612924-A3ULP0F556  UNII:A3ULP0F556  OMIM:612924
# 5    10483-OMIM:145600-F64QU97QCR  UNII:F64QU97QCR  OMIM:145600
# 35   10591-OMIM:168300-K94FTS1806  UNII:K94FTS1806  OMIM:168300
# 52   10593-OMIM:601144-L628TT009W  UNII:L628TT009W  OMIM:601144
# 56   10593-OMIM:608567-N7Z035406B  UNII:N7Z035406B  OMIM:608567
# ..                            ...              ...          ...
# 660   8979-OMIM:615214-66Y330CJHS  UNII:66Y330CJHS  OMIM:615214
# 663   9115-OMIM:212065-O26FZP769L  UNII:O26FZP769L  OMIM:212065
# 670   9413-OMIM:615966-66Y330CJHS  UNII:66Y330CJHS  OMIM:615966
# 673   9577-OMIM:614023-452VLY9402  UNII:452VLY9402  OMIM:614023
# 689   9831-OMIM:609889-P9G3CKZ4P5  UNII:P9G3CKZ4P5  OMIM:609889
#
#                   drug_name                                       disease_name
# 4                Eculizumab  HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...
# 5                Dantrolene       MALIGNANT HYPERTHERMIA, SUSCEPTIBILITY TO, 1
# 35               Flecainide       PARAMYOTONIA CONGENITA OF VON EULENBURG; PMC
# 52             Isoprenaline                         BRUGADA SYNDROME 1; BRGDA1
# 56               Cilostazol                        SICK SINUS SYNDROME 1; SSS1
# ..                      ...                                                ...
# 660  Human immunoglobulin G          AGAMMAGLOBULINEMIA 7, AUTOSOMAL RECESSIVE
# 663               Lorazepam  CONGENITAL DISORDER OF GLYCOSYLATION, TYPE Ia;...
# 670  Human immunoglobulin G  IMMUNODEFICIENCY 26 WITH OR WITHOUT NEUROLOGIC...
# 673                  Serine               PHOSPHOSERINE PHOSPHATASE DEFICIENCY
# 689             Ganciclovir  ALPHA/BETA T-CELL LYMPHOPENIA WITH GAMMA/DELTA...
#
# [94 rows x 5 columns]

# %%
data_full = pd.concat([df_oopd, df_gtrx])
data_full.to_csv("data_full.tsv", sep="\t", index=False)
data_full
# Out:
#                               _id                     drug_id     disease_id  \
# 2070  ACTRVOBWPAIOHC-XIXRPRMCSA-N    PUBCHEM.COMPOUND:2724354  UMLS:C0149921
# 1927  APKFDSVGJQXUKY-INPOYWNPSA-N    PUBCHEM.COMPOUND:5280965  UMLS:C0085436
# 628   APKFDSVGJQXUKY-VTPNKFOWSA-N  PUBCHEM.COMPOUND:118705500  UMLS:C1262313
# 1229  AQHHHDLHHXJYJD-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4946  UMLS:C0018916
# 49    AUFUWRKPQLGTGF-FMKGYKFTSA-N      PUBCHEM.COMPOUND:20058  UMLS:C0268130
# ...                           ...                         ...            ...
# 660   8979-OMIM:615214-66Y330CJHS             UNII:66Y330CJHS    OMIM:615214
# 663   9115-OMIM:212065-O26FZP769L             UNII:O26FZP769L    OMIM:212065
# 670   9413-OMIM:615966-66Y330CJHS             UNII:66Y330CJHS    OMIM:615966
# 673   9577-OMIM:614023-452VLY9402             UNII:452VLY9402    OMIM:614023
# 689   9831-OMIM:609889-P9G3CKZ4P5             UNII:P9G3CKZ4P5    OMIM:609889
#
#                          drug_name  \
# 2070                      Succimer
# 1927      Liposomal amphotericin B
# 628   Amphotericin B lipid complex
# 1229                   propranolol
# 49              uridine triacetate
# ...                            ...
# 660         Human immunoglobulin G
# 663                      Lorazepam
# 670         Human immunoglobulin G
# 673                         Serine
# 689                    Ganciclovir
#
#                                            disease_name
# 2070                         lead poisoning in children
# 1927                            Cryptococcal meningitis
# 628                          Invasive Fungal Infections
# 1229                                        Hemangiomas
# 49                                      OROTIC ACIDURIA
# ...                                                 ...
# 660           AGAMMAGLOBULINEMIA 7, AUTOSOMAL RECESSIVE
# 663   CONGENITAL DISORDER OF GLYCOSYLATION, TYPE Ia;...
# 670   IMMUNODEFICIENCY 26 WITH OR WITHOUT NEUROLOGIC...
# 673                PHOSPHOSERINE PHOSPHATASE DEFICIENCY
# 689   ALPHA/BETA T-CELL LYMPHOPENIA WITH GAMMA/DELTA...
#
# [179 rows x 5 columns]

# %%
data_tsv = data_full.sample(n=50, random_state=3000)
data_tsv.to_csv("data.tsv", sep="\t", index=False)
data_tsv
# Out:
#                                _id                     drug_id  \
# 312    2519-OMIM:615897-66Y330CJHS             UNII:66Y330CJHS
# 49     AUFUWRKPQLGTGF-FMKGYKFTSA-N      PUBCHEM.COMPOUND:20058
# 99    10969-OMIM:212140-0G389FZZ9M             UNII:0G389FZZ9M
# 2983   FWYSMLBETOMXAG-QHCPKHFHSA-N   PUBCHEM.COMPOUND:45138674
# 3637   YQNQNVDNTFHQSW-UHFFFAOYSA-N      PUBCHEM.COMPOUND:41684
# 1291   YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596
# 544      6269-ORPHA:130-L628TT009W             UNII:L628TT009W
# 151    1304-OMIM:607398-WI4X0X7BPJ             UNII:WI4X0X7BPJ
# 1089   LFQSCWFLJHTTHZ-UHFFFAOYSA-N        PUBCHEM.COMPOUND:702
# 426    4170-ORPHA:79277-9VU1KI44GP             UNII:9VU1KI44GP
# 116   11117-OMIM:253550-5Z9SP3X666             UNII:5Z9SP3X666
# 360    QXWYKJLNLSIPIN-JGVFFNPUSA-N      PUBCHEM.COMPOUND:92974
# 125   11621-OMIM:600496-839I73S42A             UNII:839I73S42A
# 205    1699-OMIM:612692-66Y330CJHS             UNII:66Y330CJHS
# 3408   XRASPMIURGNCCH-UHFFFAOYSA-N      PUBCHEM.COMPOUND:68740
# 232    DDLIGBOFAVUZHB-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4192
# 273   19750-OMIM:243150-66Y330CJHS             UNII:66Y330CJHS
# 1722   NGCGMRBZPXEPOZ-HBBGHHHDSA-N   PUBCHEM.COMPOUND:11980076
# 455     438-OMIM:241510-Z633861EIM             UNII:Z633861EIM
# 2708   VPZRWNZGLKXFOE-UHFFFAOYSA-M       PUBCHEM.COMPOUND:5258
# 2128   VSNHCAURESNICA-UHFFFAOYSA-N       PUBCHEM.COMPOUND:3657
# 1903   ZHSKUOZOLHMKEA-UHFFFAOYSA-N      PUBCHEM.COMPOUND:77082
# 535    KPYSYYIEGFHWSV-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2284
# 408    3551-OMIM:306900-27Y83O992Q             UNII:27Y83O992Q
# 119    1133-OMIM:300755-66Y330CJHS             UNII:66Y330CJHS
# 599    7577-OMIM:192600-GFO928U8MQ             UNII:GFO928U8MQ
# 98    10936-OMIM:617239-19QM69HH21             UNII:19QM69HH21
# 1346   OPXLLQIJSORQAM-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4030
# 180   14537-OMIM:607625-ADN3S497AZ             UNII:ADN3S497AZ
# 3029   ZDXPYRJPNDTMRX-VKHMYHEASA-N       PUBCHEM.COMPOUND:5961
# 3078   GIUYCYHIANZCFB-FJFJXFQQSA-N      PUBCHEM.COMPOUND:30751
# 201    1673-OMIM:615617-66Y330CJHS             UNII:66Y330CJHS
# 3381   QEEAPRPFLLJWCF-UHFFFAOYSA-K      PUBCHEM.COMPOUND:13344
# 391    3436-OMIM:278760-9VU1KI44GP             UNII:9VU1KI44GP
# 123   11445-OMIM:613101-6PLQ3CP4P3             UNII:6PLQ3CP4P3
# 515    5391-OMIM:607016-WP58SVM6R4             UNII:WP58SVM6R4
# 4      WYQPLTPSGFELIB-JTQPXKBDSA-N     PUBCHEM.COMPOUND:443936
# 1286   YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596
# 636    8646-OMIM:264070-EGX657432I             UNII:EGX657432I
# 497    GSDSWSVVBLHKDQ-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4583
# 3264   NWIBSHFKIJFRCO-WUDYKRTCSA-N       PUBCHEM.COMPOUND:5746
# 689    9831-OMIM:609889-P9G3CKZ4P5             UNII:P9G3CKZ4P5
# 3311   JGWRKYUXBBNENE-UHFFFAOYSA-N   PUBCHEM.COMPOUND:25151352
# 3861   HXHWSAZORRCQMX-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2082
# 3374   HOMGKSMUEGBAAB-UHFFFAOYSA-N       PUBCHEM.COMPOUND:3690
# 305    2439-OMIM:617014-5TAA004E22             UNII:5TAA004E22
# 527    5965-OMIM:612567-B72HH48FLU             UNII:B72HH48FLU
# 1742   KLEGMTRDCCDFJK-XDQSQZFTSA-N  PUBCHEM.COMPOUND:121492004
# 518    5541-OMIM:601495-66Y330CJHS             UNII:66Y330CJHS
# 317    2548-OMIM:261100-Q40X8H422O             UNII:Q40X8H422O
#
#                  disease_id                   drug_name  \
# 312             OMIM:615897      Human immunoglobulin G
# 49            UMLS:C0268130          uridine triacetate
# 99              OMIM:212140               Levocarnitine
# 2983          UMLS:C0205725                  letermovir
# 3637          UMLS:C0010418                Nitazoxanide
# 1291          UMLS:C0221013           Imatinib mesylate
# 544     OMIM:6269-ORPHA:130                Isoprenaline
# 151             OMIM:607398              Hydrocortisone
# 1089          UMLS:C4551472          dehydrated alcohol
# 426   OMIM:4170-ORPHA:79277                   Vitamin D
# 116             OMIM:253550                  Nusinersen
# 360           UMLS:C0393911                   droxidopa
# 125             OMIM:600496                 Liraglutide
# 205             OMIM:612692      Human immunoglobulin G
# 3408          UMLS:C0020437                 Zoledronate
# 232           UMLS:C1959629                   midazolam
# 273             OMIM:243150      Human immunoglobulin G
# 1722          UMLS:C0341862         Gonadorelin acetate
# 455             OMIM:241510               Asfotase alfa
# 2708          UMLS:C1291575       sodium phenylbutyrate
# 2128          UMLS:C0037054                 Hydroxyurea
# 1903          UMLS:C1955690  bendamustine hydrochloride
# 535           UMLS:C0270780                    baclofen
# 408             OMIM:306900          Nonacog beta pegol
# 119             OMIM:300755      Human immunoglobulin G
# 599             OMIM:192600                Disopyramide
# 98              OMIM:617239              Pyridostigmine
# 1346          UMLS:C0040954                 mebendazole
# 180             OMIM:607625                   Miglustat
# 3029          UMLS:C0024523                   Glutamine
# 3078          UMLS:C0278791       Fludarabine phosphate
# 201             OMIM:615617      Human immunoglobulin G
# 3381          UMLS:C0558595           Potassium citrate
# 391             OMIM:278760                   Vitamin D
# 123             OMIM:613101                   Etoposide
# 515             OMIM:607016                  Laronidase
# 4             UMLS:C4325554               difluprednate
# 1286          UMLS:C0812325           Imatinib mesylate
# 636             OMIM:264070                 Sapropterin
# 497           UMLS:C0010043                   Ofloxacin
# 3264          UMLS:C4087468                   mitomycin
# 689             OMIM:609889                 Ganciclovir
# 3311          UMLS:C0039106                pexidartinib
# 3861          UMLS:C0152069                 Albendazole
# 3374          UMLS:C0855197                  Ifosfamide
# 305             OMIM:617014                Sargramostim
# 527             OMIM:612567                  Infliximab
# 1742          UMLS:C0002726                   Inotersen
# 518             OMIM:601495      Human immunoglobulin G
# 317             OMIM:261100            Hydroxocobalamin
#
#                                            disease_name
# 312                                 IMMUNODEFICIENCY 24
# 49                                      OROTIC ACIDURIA
# 99               CARNITINE DEFICIENCY, SYSTEMIC PRIMARY
# 2983                              Human cytomegalovirus
# 3637                                  Cryptosporidiosis
# 1291                              Systemic mastocytosis
# 544                                    Brugada syndrome
# 151                  GLUCOCORTICOID DEFICIENCY 2; GCCD2
# 1089            Hypertrophic obstructive cardiomyopathy
# 426                 Congenital erythropoietic porphyria
# 116                    SPINAL MUSCULAR ATROPHY, TYPE II
# 360                                   Autonomic failure
# 125        MATURITY-ONSET DIABETES OF THE YOUNG, TYPE 3
# 205           AGAMMAGLOBULINEMIA 6, AUTOSOMAL RECESSIVE
# 3408                                      Hypercalcemia
# 232                                             Seizure
# 273   GASTROINTESTINAL DEFECTS AND IMMUNODEFICIENCY ...
# 1722                            Hypothalamic amenorrhea
# 455                         HYPOPHOSPHATASIA, CHILDHOOD
# 2708                         Ornithine Transcarbamylase
# 2128                                       Hemoglobin S
# 1903           Extranodal marginal zone B-cell lymphoma
# 535                             Degenerative myelopathy
# 408                                        HEMOPHILIA B
# 119                        AGAMMAGLOBULINEMIA, X-LINKED
# 599      CARDIOMYOPATHY, FAMILIAL HYPERTROPHIC, 1; CMH1
# 98    MYASTHENIC SYNDROME, CONGENITAL, 21, PRESYNAPT...
# 1346                                           whipworm
# 180                       NIEMANN-PICK DISEASE, TYPE C2
# 3029                                      Malabsorption
# 3078                                     Refractory CLL
# 201                                 IMMUNODEFICIENCY 19
# 3381                          Uric acid nephrolithiasis
# 391      XERODERMA PIGMENTOSUM, COMPLEMENTATION GROUP F
# 123   HEMOPHAGOCYTIC LYMPHOHISTIOCYTOSIS, FAMILIAL, ...
# 515                                     SCHEIE SYNDROME
# 4                            Traumatic anterior uveitis
# 1286                                 Growth Factor Gene
# 636             HYPERPHENYLALANINEMIA, BH4-DEFICIENT, D
# 497                                      corneal ulcers
# 3264    Transitional Cell Carcinoma of the Renal Pelvis
# 689   ALPHA/BETA T-CELL LYMPHOPENIA WITH GAMMA/DELTA...
# 3311                   Pigmented villonodular synovitis
# 3861                            Alveolar echinococcosis
# 3374                                  Testicular Cancer
# 305   NEUTROPENIA, SEVERE CONGENITAL, 7, AUTOSOMAL R...
# 527   INFLAMMATORY BOWEL DISEASE 25, AUTOSOMAL RECES...
# 1742                                        Amyloidosis
# 518           AGAMMAGLOBULINEMIA 1, AUTOSOMAL RECESSIVE
# 317                       IMERSLUND-GRASBECK SYNDROME 1
