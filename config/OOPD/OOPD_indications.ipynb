# %% [markdown]
# # OOPD (orphan drugs)
# - from API url listed in [github issue](https://github.com/TranslatorSRI/Benchmarks/issues/20) (mychem.info)

# %%
import pandas as pd
import requests

# %%
from biothings_client import get_client

mc = get_client('chem')
drugs = mc.query(
        '_exists_:fda_orphan_drug', 
        fields='fda_orphan_drug',
        fetch_all=True)

# %%
# url = 'https://mychem.info/v1/query?q=_exists_:fda_orphan_drug&fields=fda_orphan_drug&fetch_all=True'
# data = requests.get(url)
# drugs = data.json()
# drugs = drugs['hits']

# %%
df = pd.DataFrame(columns=['_id', 'drug_pubchem_cid', 'disease_umls', 'drug_name', 'disease_name', 'status', 'date'])

for drug in drugs:
    
    _id = drug['_id']
    
    # orphan designation 
    for use in drug['fda_orphan_drug']:

        # designation status/approval (may be useful for filtering)
        status = use['designation_status']
        date = use['designated_date']
            

        if isinstance(use['orphan_designation']['umls'], list):
            names = use['orphan_designation']['parsed_text']
            umls = use['orphan_designation']['umls']
        else:
            names = [use['orphan_designation']['parsed_text']]
            umls = [use['orphan_designation']['umls']]
        # for now, skip if there are nested lists of names
        if any(isinstance(el, list) for el in names):
            continue
        name_uml_dict = dict(zip(names, umls))
        
        if 'pubchem_cid' in use.keys():
            if isinstance(use['pubchem_cid'], list):
                continue
            cid = 'PUBCHEM.COMPOUND:' + str(use['pubchem_cid'])
        else:
            cid = ''
            # only include cases where a pubchem cid exists (used for querying)
            continue

        for name, uml in name_uml_dict.items():
            disease_umls = "UMLS:" + uml
            disease_name = name
            new_record = {
                '_id': _id,
                'drug_name': use['generic_name'],
                'drug_pubchem_cid': cid,
                'disease_umls': disease_umls,
                'disease_name': disease_name,
                'status': status,
                'date': date
                }
            #print(new_record)
            df.loc[len(df)] = new_record

df
# Out:
# INFO:biothings.client:Fetching 3661 chem(s) . . .
# ERROR:biothings.client:No more results to return.
#                               _id           drug_pubchem_cid   disease_umls  \
# 0     WXXSNCNJFUAIDG-UHFFFAOYSA-N  PUBCHEM.COMPOUND:11304743  UMLS:C0036421
# 1     WXXSNCNJFUAIDG-UHFFFAOYSA-N  PUBCHEM.COMPOUND:11304743  UMLS:C3203102
# 2     WXXSNCNJFUAIDG-UHFFFAOYSA-N  PUBCHEM.COMPOUND:11304743  UMLS:C2363973
# 3     WYQPLTPSGFELIB-JTQPXKBDSA-N    PUBCHEM.COMPOUND:443936  UMLS:C0030343
# 4     WYQPLTPSGFELIB-JTQPXKBDSA-N    PUBCHEM.COMPOUND:443936  UMLS:C4325554
# ...                           ...                        ...            ...
# 3910  QUIJNHUBAXPXFS-XLJNKUFUSA-N   PUBCHEM.COMPOUND:5388906  UMLS:C0041296
# 3911  QUIJNHUBAXPXFS-XLJNKUFUSA-N   PUBCHEM.COMPOUND:5388906  UMLS:C0041296
# 3912  QUIJNHUBAXPXFS-XLJNKUFUSA-N   PUBCHEM.COMPOUND:5388906  UMLS:C0009450
# 3913  QUIJNHUBAXPXFS-XLJNKUFUSA-N   PUBCHEM.COMPOUND:5388906  UMLS:C0026912
# 3914  QUIJNHUBAXPXFS-XLJNKUFUSA-N   PUBCHEM.COMPOUND:5388906  UMLS:C0041296
#
#           drug_name                                   disease_name  \
# 0         riociguat                             Systemic sclerosis
# 1         riociguat                PULMONARY ARTERIAL HYPERTENSION
# 2         riociguat  Chronic thromboembolic pulmonary hypertension
# 3     difluprednate                                     Panuveitis
# 4     difluprednate                     Traumatic anterior uveitis
# ...             ...                                            ...
# 3910    bedaquiline                            Active Tuberculosis
# 3911    bedaquiline                            Active Tuberculosis
# 3912    Bedaquiline                                      Infection
# 3913    Bedaquiline                                   Mycobacteria
# 3914    bedaquiline                            Active Tuberculosis
#
#                     status        date
# 0     Designated/Withdrawn  2014-07-24
# 1      Designated/Approved  2013-09-19
# 2      Designated/Approved  2013-09-19
# 3      Designated/Approved  2008-09-30
# 4      Designated/Approved  2008-09-30
# ...                    ...         ...
# 3910   Designated/Approved  2005-01-10
# 3911   Designated/Approved  2005-01-10
# 3912            Designated  2017-07-27
# 3913            Designated  2017-07-27
# 3914   Designated/Approved  2005-01-10
#
# [3915 rows x 7 columns]

# %%
# steps from DrugCentral_creative Benchmark get_indications.py

# sort
df = df.sort_values('_id')

df.to_csv("data_full.tsv", sep="\t", index=False)

# restrict to only 1 drug per disease
df = df.drop_duplicates('disease_umls', keep=False)
df
# Out:
#                               _id            drug_pubchem_cid   disease_umls  \
# 1266  ACRHBAYQBXXRTO-OAQYLSRUSA-N     PUBCHEM.COMPOUND:132999  UMLS:C0340515
# 2743  ACSROKXFXFNERX-UHFFFAOYSA-N      PUBCHEM.COMPOUND:51711  UMLS:C0338656
# 2070  ACTRVOBWPAIOHC-XIXRPRMCSA-N    PUBCHEM.COMPOUND:2724354  UMLS:C0149921
# 2069  ACTRVOBWPAIOHC-XIXRPRMCSA-N    PUBCHEM.COMPOUND:2724354  UMLS:C0728899
# 2000  AKJHMTWEGVYYSE-FXILSDISSA-N    PUBCHEM.COMPOUND:5288209  UMLS:C2700204
# ...                           ...                         ...            ...
# 3640  ZNNLBTZKUZBEKO-UHFFFAOYSA-N       PUBCHEM.COMPOUND:3488  UMLS:C0948008
# 3848  ZSSLCFLHEFXANG-GOSISDBHSA-N   PUBCHEM.COMPOUND:25052630  UMLS:C0020542
# 3451  ZUJBBVJXXYRPFS-DYKIIFRCSA-N   PUBCHEM.COMPOUND:71722017  UMLS:C1096155
# 842   ZXFWJPKXEMFBOG-LWVMDMHWSA-N  PUBCHEM.COMPOUND:118984442  UMLS:C0022660
# 2769  ZYRLHJIMTROTBO-UHFFFAOYSA-N   PUBCHEM.COMPOUND:24770514  UMLS:C0006413
#
#                              drug_name                    disease_name  \
# 1266                        ivabradine               heart dysfunction
# 2743              Pramiracetam Sulfate           Cognitive Dysfunction
# 2070                          Succimer      lead poisoning in children
# 2069                          Succimer                    Intoxication
# 2000                       fenretinide      Follicular T-cell lymphoma
# ...                                ...                             ...
# 3640                         Glyburide                 Ischemic stroke
# 3848                        Zamicastat          Pulmonary Hypertension
# 3451                        dusquetide  Macrophage Activation Syndrome
# 842                  Anaritide acetate             Acute renal failure
# 2769  6,8-bis(benzylthio)octanoic acid               Burkitts Lymphoma
#
#                     status        date
# 1266  Designated/Withdrawn  2018-07-09
# 2743  Designated/Withdrawn  1991-11-04
# 2070   Designated/Approved  1984-05-09
# 2069            Designated  1991-03-22
# 2000            Designated  2017-12-22
# ...                    ...         ...
# 3640            Designated  2017-01-12
# 3848            Designated  2019-07-15
# 3451            Designated  2016-08-10
# 842   Designated/Withdrawn  1992-08-27
# 2769            Designated  2018-01-25
#
# [454 rows x 7 columns]

# %%
approved_df = df.loc[df['status'] == 'Designated/Approved']

data_tsv = approved_df.sample(50, random_state=3000)
data_tsv.to_csv("data.tsv", sep="\t", index=False)
data_tsv
# Out:
#                               _id            drug_pubchem_cid   disease_umls  \
# 1502  KTEIFNKAUNYNJU-GFCCVEGCSA-N   PUBCHEM.COMPOUND:11626560  UMLS:C0024302
# 3311  JGWRKYUXBBNENE-UHFFFAOYSA-N   PUBCHEM.COMPOUND:25151352  UMLS:C0039106
# 1409  YFGHCGITMMYXAQ-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4236  UMLS:C4551761
# 3862  HXHWSAZORRCQMX-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2082  UMLS:C4553297
# 3861  HXHWSAZORRCQMX-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2082  UMLS:C0152069
# 2331  UUVWYPNAQBNQJQ-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2123  UMLS:C5204526
# 2527  CYOHGALHFOKKQC-UHFFFAOYSA-N   PUBCHEM.COMPOUND:10127622  UMLS:C0027831
# 361   QXWYKJLNLSIPIN-JGVFFNPUSA-N      PUBCHEM.COMPOUND:92974  UMLS:C1291314
# 1291  YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596  UMLS:C0221013
# 3700  GAQMWPRWVIGRRV-IVDGIBIRSA-N   PUBCHEM.COMPOUND:70683024  UMLS:C0854467
# 2444  XNSAINXGIQZQOO-UHFFFAOYSA-N      PUBCHEM.COMPOUND:32281  UMLS:C0007097
# 497   GSDSWSVVBLHKDQ-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4583  UMLS:C0010043
# 1722  NGCGMRBZPXEPOZ-HBBGHHHDSA-N   PUBCHEM.COMPOUND:11980076  UMLS:C0341862
# 3574  UHTHHESEBZOYNR-UHFFFAOYSA-N    PUBCHEM.COMPOUND:3081361  UMLS:C0278851
# 359   QXWYKJLNLSIPIN-JGVFFNPUSA-N      PUBCHEM.COMPOUND:92974  UMLS:C0259749
# 154   RUDATBOHQWOJDD-BSWAIDMHSA-N      PUBCHEM.COMPOUND:10133  UMLS:C0442893
# 49    AUFUWRKPQLGTGF-FMKGYKFTSA-N      PUBCHEM.COMPOUND:20058  UMLS:C0268130
# 1742  KLEGMTRDCCDFJK-XDQSQZFTSA-N  PUBCHEM.COMPOUND:121492004  UMLS:C0002726
# 1902  ZHSKUOZOLHMKEA-UHFFFAOYSA-N      PUBCHEM.COMPOUND:77082  UMLS:C0855139
# 536   KPYSYYIEGFHWSV-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2284  UMLS:C1384641
# 4     WYQPLTPSGFELIB-JTQPXKBDSA-N     PUBCHEM.COMPOUND:443936  UMLS:C4325554
# 2128  VSNHCAURESNICA-UHFFFAOYSA-N       PUBCHEM.COMPOUND:3657  UMLS:C0037054
# 2328  UREBDLICKHMUKA-CXSFZGCWSA-N       PUBCHEM.COMPOUND:5743  UMLS:C3538749
# 1346  OPXLLQIJSORQAM-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4030  UMLS:C0040954
# 3     WYQPLTPSGFELIB-JTQPXKBDSA-N     PUBCHEM.COMPOUND:443936  UMLS:C0030343
# 2983  FWYSMLBETOMXAG-QHCPKHFHSA-N   PUBCHEM.COMPOUND:45138674  UMLS:C0205725
# 3206  PJHKBYALYHRYSK-UHFFFAOYSA-N      PUBCHEM.COMPOUND:69286  UMLS:C1456270
# 2114  VDHAWDNDOKGFTD-MRXNPFEDSA-N     PUBCHEM.COMPOUND:156419  UMLS:C0687150
# 2070  ACTRVOBWPAIOHC-XIXRPRMCSA-N    PUBCHEM.COMPOUND:2724354  UMLS:C0149921
# 3384  QEEAPRPFLLJWCF-UHFFFAOYSA-K      PUBCHEM.COMPOUND:13344  UMLS:C0023869
# 360   QXWYKJLNLSIPIN-JGVFFNPUSA-N      PUBCHEM.COMPOUND:92974  UMLS:C0393911
# 232   DDLIGBOFAVUZHB-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4192  UMLS:C1959629
# 105   OGBMKVWORPGQRR-UMXFMPSGSA-N   PUBCHEM.COMPOUND:16133850  UMLS:C0020598
# 1494  IXOXBSCIXZEQEQ-UHTZMRCNSA-N    PUBCHEM.COMPOUND:3011155  UMLS:C1961102
# 298   IAKHMKGGTNLKSZ-INIZCTEOSA-N       PUBCHEM.COMPOUND:6167  UMLS:C0031069
# 3029  ZDXPYRJPNDTMRX-VKHMYHEASA-N       PUBCHEM.COMPOUND:5961  UMLS:C0024523
# 2041  DQJDBUPLRMRBAB-WZTVWXICSA-N   PUBCHEM.COMPOUND:24970412  UMLS:C0268407
# 308   HDHDTKMUACZDAA-PHNIDTBTSA-N   PUBCHEM.COMPOUND:11993702  UMLS:C3554225
# 1723  NGCGMRBZPXEPOZ-HBBGHHHDSA-N   PUBCHEM.COMPOUND:11980076  UMLS:C1689985
# 3078  GIUYCYHIANZCFB-FJFJXFQQSA-N      PUBCHEM.COMPOUND:30751  UMLS:C0278791
# 534   KPYSYYIEGFHWSV-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2284  UMLS:C0037933
# 3015  XFCLJVABOIYOMF-QPLCGJKRSA-N    PUBCHEM.COMPOUND:3005573  UMLS:C1384494
# 3448  KKZJGLLVHKMTCM-UHFFFAOYSA-N       PUBCHEM.COMPOUND:4212  UMLS:C1328504
# 2330  UUVWYPNAQBNQJQ-UHFFFAOYSA-N       PUBCHEM.COMPOUND:2123  UMLS:C0948216
# 1289  YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596  UMLS:C0346421
# 2131  FWCVZAQENIZVMY-UHFFFAOYSA-N   PUBCHEM.COMPOUND:71602803  UMLS:C0085298
# 1320  LCQLHJZYVOQKHU-VKHMYHEASA-N     PUBCHEM.COMPOUND:121396  UMLS:C1829844
# 1288  YLMAHDNUQAMNNX-UHFFFAOYSA-N     PUBCHEM.COMPOUND:123596  UMLS:C0206141
# 3382  QEEAPRPFLLJWCF-UHFFFAOYSA-K      PUBCHEM.COMPOUND:13344  UMLS:C0009566
# 2243  DHMTURDWPRKSOA-RUZDIDTESA-N     PUBCHEM.COMPOUND:148195  UMLS:C0033300
#
#                        drug_name                           disease_name  \
# 1502                  crizotinib                    large cell lymphoma
# 3311                pexidartinib       Pigmented villonodular synovitis
# 1409                   Modafinil           Excessive daytime sleepiness
# 3862                 Albendazole                        Hydatid Disease
# 3861                 Albendazole                Alveolar echinococcosis
# 2331                 Altretamine                Advanced Adenocarcinoma
# 2527                 selumetinib               Neurofibromatosis type 1
# 361                    droxidopa                 hydroxylase deficiency
# 1291           Imatinib mesylate                  Systemic mastocytosis
# 3700               Pegfilgrastim                       Myelosuppression
# 2444            Thyrotropin alfa                             Carcinomas
# 497                    Ofloxacin                         corneal ulcers
# 1722         Gonadorelin acetate                Hypothalamic amenorrhea
# 3574                  vandetanib                      Thyroid carcinoma
# 359                    droxidopa                   Autonomic neuropathy
# 154                    chenodiol                       Systemic disease
# 49            uridine triacetate                        OROTIC ACIDURIA
# 1742                   Inotersen                            Amyloidosis
# 1902  bendamustine hydrochloride           Nodal Marginal Zone Lymphoma
# 536                     baclofen                   Cervical spondylosis
# 4                  difluprednate             Traumatic anterior uveitis
# 2128                 Hydroxyurea                           Hemoglobin S
# 2328               dexamethasone                                Myeloma
# 1346                 mebendazole                               whipworm
# 3                  difluprednate                             Panuveitis
# 2983                  letermovir                  Human cytomegalovirus
# 3206                triheptanoin          fatty acid oxidation disorder
# 2114                  cinacalcet                  Parathyroid Carcinoma
# 2070                    Succimer             lead poisoning in children
# 3384           Potassium citrate                              Lithiasis
# 360                    droxidopa                      Autonomic failure
# 232                    midazolam                                Seizure
# 105                 Teriparatide                           Hypocalcemia
# 1494                  nelarabine           Acute Lymphoblastic Leukemia
# 298                   colchicine           Familial Mediterranean Fever
# 3029                   Glutamine                          Malabsorption
# 2041         tafamidis meglumine                 Amyloid cardiomyopathy
# 308                setmelanotide             LEPTIN RECEPTOR DEFICIENCY
# 1723         Gonadorelin acetate                                Absence
# 3078       Fludarabine phosphate                         Refractory CLL
# 534                     baclofen                        Spinal Diseases
# 3015                  Toremifene                   Metastatic Carcinoma
# 3448                Mitoxantrone     Hormone refractory prostate cancer
# 2330                 Altretamine            Adenocarcinoma of the Ovary
# 1289           Imatinib mesylate          Chronic eosinophilic leukemia
# 2131                   Voxelotor                                    SCD
# 1320              carglumic acid                      Organic acidemias
# 1288           Imatinib mesylate  Idiopathic Hypereosinophilic Syndrome
# 3382           Potassium citrate                           Complication
# 2243                  lonafarnib   Hutchinson-Gilford Progeria Syndrome
#
#                    status        date
# 1502  Designated/Approved  2012-09-28
# 3311  Designated/Approved  2014-02-14
# 1409  Designated/Approved  1993-03-15
# 3862  Designated/Approved  1996-01-17
# 3861  Designated/Approved  1996-01-17
# 2331  Designated/Approved  1984-02-09
# 2527  Designated/Approved  2018-02-14
# 361   Designated/Approved  2007-01-17
# 1291  Designated/Approved  2005-09-09
# 3700  Designated/Approved  2013-11-20
# 2444  Designated/Approved  2001-08-03
# 497   Designated/Approved  1991-04-18
# 1722  Designated/Approved  1987-04-22
# 3574  Designated/Approved  2005-10-21
# 359   Designated/Approved  2007-01-17
# 154   Designated/Approved  1984-09-21
# 49    Designated/Approved  2013-08-09
# 1742  Designated/Approved  2012-07-24
# 1902  Designated/Approved  2013-11-26
# 536   Designated/Approved  1987-11-10
# 4     Designated/Approved  2008-09-30
# 2128  Designated/Approved  1990-10-01
# 2328  Designated/Approved  2018-03-26
# 1346  Designated/Approved  2014-09-03
# 3     Designated/Approved  2008-09-30
# 2983  Designated/Approved  2011-12-12
# 3206  Designated/Approved  2015-04-15
# 2114  Designated/Approved  2003-05-12
# 2070  Designated/Approved  1984-05-09
# 3384  Designated/Approved  1984-11-01
# 360   Designated/Approved  2007-01-17
# 232   Designated/Approved  2009-10-20
# 105   Designated/Approved  1987-01-09
# 1494  Designated/Approved  2004-08-10
# 298   Designated/Approved  2007-09-25
# 3029  Designated/Approved  1995-03-06
# 2041  Designated/Approved  2012-02-17
# 308   Designated/Approved  2017-11-27
# 1723  Designated/Approved  1987-04-22
# 3078  Designated/Approved  1989-04-18
# 534   Designated/Approved  1987-11-10
# 3015  Designated/Approved  1991-09-19
# 3448  Designated/Approved  1996-08-21
# 2330  Designated/Approved  1984-02-09
# 1289  Designated/Approved  2005-08-25
# 2131  Designated/Approved  2015-12-29
# 1320  Designated/Approved  2014-06-17
# 1288  Designated/Approved  2005-08-25
# 3382  Designated/Approved  1984-11-01
# 2243  Designated/Approved  2011-04-18
