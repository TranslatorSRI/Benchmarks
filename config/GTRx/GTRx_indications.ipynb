# %% [markdown]
# # GTRx
# - from API url listed in [github issue](https://github.com/TranslatorSRI/Benchmarks/issues/20)
#     - [API documentation](https://github.com/biothings/GTRx/tree/3bd9d1cfb63056dc455e5770b52690894d1ba7c9/)
# - Inxight IDs are the same as UNII according to [this comment](https://github.com/NCATS-Tangerine/translator-api-registry/pull/109#issuecomment-1367609032)

# %%
import pandas as pd
import requests

# %%
url = 'https://biothings.ncats.io/gtrx/query?q=predicate:treated_by&fetch_all=True'
data = requests.get(url)
drugs = data.json()
gtrx = drugs['hits']
#gtrx

# %%
df = pd.DataFrame(columns=['_id', 'drug_inxight', 'disease_omim', 'drug_name', 'disease_name', 'nref'])

for entry in gtrx:
    # association id
    _id = entry['_id']
    
    # drug info
    # all drug names/ids hyphenated if multiple entries
    drug_name = ''
    drug_inxight = ''
    for drug in entry['object']['intervention']:
        drug_name += (drug['description'] + '-')
        drug_inxight += ('UNII:' + drug['inxight'] + '-')
        
    drug_name = drug_name[:-1]
    drug_inxight = drug_inxight[:-1]
    
    # disease info
    disease_name = entry['subject']['condition_name']
    #disease_name = ','.join(entry['subject']['alternate_names'])
    disease_omim = 'OMIM:' + entry['subject']['omim']
    
    # number of references
    nref = len(entry['references'])
    
    new_record = {
        '_id': _id,
        'drug_name': drug_name,
        'drug_inxight': drug_inxight,
        'disease_name': disease_name,
        'disease_omim': disease_omim,
        'nref': nref
    }
    df.loc[len(df)] = new_record

df
# Out:
#                                                    _id  \
# 0                         10031-OMIM:250250-66Y330CJHS
# 1                         10031-OMIM:250250-H1250JIK0A
# 2                         10031-OMIM:250250-MZ1IW7Q79D
# 3    10301-OMIM:612562-J06Y7MXW4D-V8G4MOF2V9-2BTY8K...
# 4                          1037-OMIM:612924-A3ULP0F556
# ..                                                 ...
# 690                        9832-OMIM:603554-T5UM7HB19N
# 691  9863-OMIM:616326-19QM69HH21-L16PUN799N-3982TWQ96G
# 692                        9863-OMIM:616326-GN83C131XS
# 693                        9863-OMIM:616326-QF8SVZ843E
# 694                        9863-OMIM:616326-RU4S6E2G0J
#
#                                         drug_inxight disease_omim  \
# 0                                    UNII:66Y330CJHS  OMIM:250250
# 1                                    UNII:H1250JIK0A  OMIM:250250
# 2                                    UNII:MZ1IW7Q79D  OMIM:250250
# 3    UNII:J06Y7MXW4D-UNII:V8G4MOF2V9-UNII:2BTY8KH53L  OMIM:612562
# 4                                    UNII:A3ULP0F556  OMIM:612924
# ..                                               ...          ...
# 690                                  UNII:T5UM7HB19N  OMIM:603554
# 691  UNII:19QM69HH21-UNII:L16PUN799N-UNII:3982TWQ96G  OMIM:616326
# 692                                  UNII:GN83C131XS  OMIM:616326
# 693                                  UNII:QF8SVZ843E  OMIM:616326
# 694                                  UNII:RU4S6E2G0J  OMIM:616326
#
#                                  drug_name  \
# 0                   Human immunoglobulin G
# 1                           Clarithromycin
# 2                             Valaciclovir
# 3     Deferoxamine-Deferasirox-Deferiprone
# 4                               Eculizumab
# ..                                     ...
# 690                           Hypochlorite
# 691  Pyridostigmine-Ambenonium-Neostigmine
# 692                              Ephedrine
# 693                             Salbutamol
# 694                          Amifampridine
#
#                                           disease_name  nref
# 0                       CARTILAGE-HAIR HYPOPLASIA; CHH    20
# 1                       CARTILAGE-HAIR HYPOPLASIA; CHH    20
# 2                       CARTILAGE-HAIR HYPOPLASIA; CHH    20
# 3                            DIAMOND-BLACKFAN ANEMIA 7    80
# 4    HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...     8
# ..                                                 ...   ...
# 690                                     OMENN SYNDROME    22
# 691  MYASTHENIC SYNDROME, CONGENITAL, 11, ASSOCIATE...     9
# 692  MYASTHENIC SYNDROME, CONGENITAL, 11, ASSOCIATE...     9
# 693  MYASTHENIC SYNDROME, CONGENITAL, 11, ASSOCIATE...     9
# 694  MYASTHENIC SYNDROME, CONGENITAL, 11, ASSOCIATE...     9
#
# [695 rows x 6 columns]

# %%
# steps from DrugCentral_creative get_indications.py

# sort
df = df.sort_values('_id')

df.to_csv("data_full.tsv", sep="\t", index=False)

# remove interventions with multiple drugs
df = df[~df['drug_inxight'].str.contains('-')]

# restrict to only 1 drug per disease
df = df.drop_duplicates('disease_omim', keep=False)
df
# Out:
#                               _id     drug_inxight disease_omim  \
# 4     1037-OMIM:612924-A3ULP0F556  UNII:A3ULP0F556  OMIM:612924
# 5    10483-OMIM:145600-F64QU97QCR  UNII:F64QU97QCR  OMIM:145600
# 35   10591-OMIM:168300-K94FTS1806  UNII:K94FTS1806  OMIM:168300
# 52   10593-OMIM:601144-L628TT009W  UNII:L628TT009W  OMIM:601144
# 56   10593-OMIM:608567-N7Z035406B  UNII:N7Z035406B  OMIM:608567
# ..                            ...              ...          ...
# 660   8979-OMIM:615214-66Y330CJHS  UNII:66Y330CJHS  OMIM:615214
# 663   9115-OMIM:212065-O26FZP769L  UNII:O26FZP769L  OMIM:212065
# 670   9413-OMIM:615966-66Y330CJHS  UNII:66Y330CJHS  OMIM:615966
# 673   9577-OMIM:614023-452VLY9402  UNII:452VLY9402  OMIM:614023
# 689   9831-OMIM:609889-P9G3CKZ4P5  UNII:P9G3CKZ4P5  OMIM:609889
#
#                   drug_name  \
# 4                Eculizumab
# 5                Dantrolene
# 35               Flecainide
# 52             Isoprenaline
# 56               Cilostazol
# ..                      ...
# 660  Human immunoglobulin G
# 663               Lorazepam
# 670  Human immunoglobulin G
# 673                  Serine
# 689             Ganciclovir
#
#                                           disease_name  nref
# 4    HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...     8
# 5         MALIGNANT HYPERTHERMIA, SUSCEPTIBILITY TO, 1     1
# 35        PARAMYOTONIA CONGENITA OF VON EULENBURG; PMC    12
# 52                          BRUGADA SYNDROME 1; BRGDA1    10
# 56                         SICK SINUS SYNDROME 1; SSS1    11
# ..                                                 ...   ...
# 660          AGAMMAGLOBULINEMIA 7, AUTOSOMAL RECESSIVE     3
# 663  CONGENITAL DISORDER OF GLYCOSYLATION, TYPE Ia;...     3
# 670  IMMUNODEFICIENCY 26 WITH OR WITHOUT NEUROLOGIC...    65
# 673               PHOSPHOSERINE PHOSPHATASE DEFICIENCY     5
# 689  ALPHA/BETA T-CELL LYMPHOPENIA WITH GAMMA/DELTA...     3
#
# [94 rows x 6 columns]

# %%
data_tsv = df.sample(50, random_state=3000)
data_tsv.to_csv("data.tsv", sep="\t", index=False)
data_tsv
# Out:
#                               _id     drug_inxight           disease_omim  \
# 122  11429-OMIM:603552-6PLQ3CP4P3  UNII:6PLQ3CP4P3            OMIM:603552
# 575    704-OMIM:617718-66Y330CJHS  UNII:66Y330CJHS            OMIM:617718
# 115  11117-OMIM:253400-5Z9SP3X666  UNII:5Z9SP3X666            OMIM:253400
# 273  19750-OMIM:243150-66Y330CJHS  UNII:66Y330CJHS            OMIM:243150
# 155   1366-OMIM:274150-U5SFU33XUX  UNII:U5SFU33XUX            OMIM:274150
# 465   4696-OMIM:253220-7XZ4062R17  UNII:7XZ4062R17            OMIM:253220
# 324   2578-OMIM:306400-21K6M2I7AG  UNII:21K6M2I7AG            OMIM:306400
# 329   2591-OMIM:202010-WI4X0X7BPJ  UNII:WI4X0X7BPJ            OMIM:202010
# 526   5964-OMIM:613148-B72HH48FLU  UNII:B72HH48FLU            OMIM:613148
# 408   3551-OMIM:306900-27Y83O992Q  UNII:27Y83O992Q            OMIM:306900
# 119   1133-OMIM:300755-66Y330CJHS  UNII:66Y330CJHS            OMIM:300755
# 203  16902-OMIM:614923-HG18B9YRS7  UNII:HG18B9YRS7            OMIM:614923
# 99   10969-OMIM:212140-0G389FZZ9M  UNII:0G389FZZ9M            OMIM:212140
# 623   7979-OMIM:177735-451W47IQ8X  UNII:451W47IQ8X            OMIM:177735
# 134  11784-OMIM:612926-A3ULP0F556  UNII:A3ULP0F556            OMIM:612926
# 574   6953-OMIM:612922-A3ULP0F556  UNII:A3ULP0F556            OMIM:612922
# 270   1968-OMIM:214500-46627O600J  UNII:46627O600J            OMIM:214500
# 205   1699-OMIM:612692-66Y330CJHS  UNII:66Y330CJHS            OMIM:612692
# 414   4021-OMIM:617526-EH28UP18IF  UNII:EH28UP18IF            OMIM:617526
# 97   10935-OMIM:618049-83619PEU5T  UNII:83619PEU5T            OMIM:618049
# 518   5541-OMIM:601495-66Y330CJHS  UNII:66Y330CJHS            OMIM:601495
# 56   10593-OMIM:608567-N7Z035406B  UNII:N7Z035406B            OMIM:608567
# 689   9831-OMIM:609889-P9G3CKZ4P5  UNII:P9G3CKZ4P5            OMIM:609889
# 445   4326-OMIM:149400-5PE9FDE8GB  UNII:5PE9FDE8GB            OMIM:149400
# 360  30228-OMIM:616224-19QM69HH21  UNII:19QM69HH21            OMIM:616224
# 544     6269-ORPHA:130-L628TT009W  UNII:L628TT009W    OMIM:6269-ORPHA:130
# 151   1304-OMIM:607398-WI4X0X7BPJ  UNII:WI4X0X7BPJ            OMIM:607398
# 91   10856-OMIM:222900-8A7F670F2Y  UNII:8A7F670F2Y            OMIM:222900
# 323   2578-OMIM:300645-21K6M2I7AG  UNII:21K6M2I7AG            OMIM:300645
# 510   5147-OMIM:276710-PQ6CK8PD0R  UNII:PQ6CK8PD0R            OMIM:276710
# 454    438-OMIM:241500-Z633861EIM  UNII:Z633861EIM            OMIM:241500
# 564   6617-OMIM:278000-K4YTU42T8G  UNII:K4YTU42T8G            OMIM:278000
# 406   3535-OMIM:188050-5Q7ZVV76EI  UNII:5Q7ZVV76EI            OMIM:188050
# 455    438-OMIM:241510-Z633861EIM  UNII:Z633861EIM            OMIM:241510
# 528       60-ORPHA:130-L628TT009W  UNII:L628TT009W      OMIM:60-ORPHA:130
# 4     1037-OMIM:612924-A3ULP0F556  UNII:A3ULP0F556            OMIM:612924
# 543   6257-OMIM:618856-SX6K58TVWC  UNII:SX6K58TVWC            OMIM:618856
# 515   5391-OMIM:607016-WP58SVM6R4  UNII:WP58SVM6R4            OMIM:607016
# 636   8646-OMIM:264070-EGX657432I  UNII:EGX657432I            OMIM:264070
# 198  16187-OMIM:211530-TLM2976OFR  UNII:TLM2976OFR            OMIM:211530
# 180  14537-OMIM:607625-ADN3S497AZ  UNII:ADN3S497AZ            OMIM:607625
# 670   9413-OMIM:615966-66Y330CJHS  UNII:66Y330CJHS            OMIM:615966
# 423   4065-OMIM:232300-DTI67O9503  UNII:DTI67O9503            OMIM:232300
# 117  11132-OMIM:616330-RU4S6E2G0J  UNII:RU4S6E2G0J            OMIM:616330
# 139  11920-OMIM:601859-W36ZG6FT64  UNII:W36ZG6FT64            OMIM:601859
# 374    30500-ORPHA:569-33CM23913M  UNII:33CM23913M   OMIM:30500-ORPHA:569
# 125  11621-OMIM:600496-839I73S42A  UNII:839I73S42A            OMIM:600496
# 238  19041-OMIM:615573-9G64RSX1XD  UNII:9G64RSX1XD            OMIM:615573
# 426   4170-ORPHA:79277-9VU1KI44GP  UNII:9VU1KI44GP  OMIM:4170-ORPHA:79277
# 569     68-OMIM:614857-3SCV180C9W  UNII:3SCV180C9W            OMIM:614857
#
#                   drug_name  \
# 122               Etoposide
# 575  Human immunoglobulin G
# 115              Nusinersen
# 273  Human immunoglobulin G
# 155         Apadamtase alfa
# 465       Vestronidase alfa
# 324     Interferon gamma-1b
# 329          Hydrocortisone
# 526              Infliximab
# 408      Nonacog beta pegol
# 119  Human immunoglobulin G
# 203                  Valine
# 99            Levocarnitine
# 623         Sodium chloride
# 134              Eculizumab
# 574              Eculizumab
# 270                Levodopa
# 205  Human immunoglobulin G
# 414            Isotretinoin
# 97              Pramipexole
# 518  Human immunoglobulin G
# 56               Cilostazol
# 689             Ganciclovir
# 445              Clonazepam
# 360          Pyridostigmine
# 544            Isoprenaline
# 151          Hydrocortisone
# 91              Sacrosidase
# 323     Interferon gamma-1b
# 510           Ascorbic acid
# 454           Asfotase alfa
# 564         Sebelipase alfa
# 406                Warfarin
# 455           Asfotase alfa
# 528            Isoprenaline
# 4                Eculizumab
# 543               Glyburide
# 515              Laronidase
# 636             Sapropterin
# 198              Riboflavin
# 180               Miglustat
# 670  Human immunoglobulin G
# 423      Alglucosidase alfa
# 117           Amifampridine
# 139               Sirolimus
# 374           Carbamazepine
# 125             Liraglutide
# 238               Captopril
# 426               Vitamin D
# 569         Glycine betaine
#
#                                           disease_name  nref
# 122  HEMOPHAGOCYTIC LYMPHOHISTIOCYTOSIS, FAMILIAL, ...     6
# 575  IMMUNODEFICIENCY 71 WITH INFLAMMATORY DISEASE ...     3
# 115                  SPINAL MUSCULAR ATROPHY, TYPE III     5
# 273  GASTROINTESTINAL DEFECTS AND IMMUNODEFICIENCY ...    10
# 155    THROMBOTIC THROMBOCYTOPENIC PURPURA, HEREDITARY    25
# 465                    MUCOPOLYSACCHARIDOSIS, TYPE VII     5
# 324     GRANULOMATOUS DISEASE, CHRONIC, X-LINKED; CGDX    77
# 329  ADRENAL HYPERPLASIA, CONGENITAL, DUE TO STEROI...     5
# 526  INFLAMMATORY BOWEL DISEASE 28, AUTOSOMAL RECES...    42
# 408                                       HEMOPHILIA B    23
# 119                       AGAMMAGLOBULINEMIA, X-LINKED    22
# 203  BRANCHED-CHAIN KETO ACID DEHYDROGENASE KINASE ...     2
# 99              CARNITINE DEFICIENCY, SYSTEMIC PRIMARY     4
# 623  PSEUDOHYPOALDOSTERONISM, TYPE I, AUTOSOMAL DOM...    15
# 134  HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...     8
# 574  HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...     8
# 270                      CHEDIAK-HIGASHI SYNDROME; CHS     3
# 205          AGAMMAGLOBULINEMIA 6, AUTOSOMAL RECESSIVE     6
# 414  ERYTHROKERATODERMIA VARIABILIS ET PROGRESSIVA ...     1
# 97         PARKINSONISM-DYSTONIA, INFANTILE, 2; PKDYS2     2
# 518          AGAMMAGLOBULINEMIA 1, AUTOSOMAL RECESSIVE     9
# 56                         SICK SINUS SYNDROME 1; SSS1    11
# 689  ALPHA/BETA T-CELL LYMPHOPENIA WITH GAMMA/DELTA...     3
# 445                                    HYPEREKPLEXIA 1    18
# 360                MYASTHENIC SYNDROME, CONGENITAL, 22     4
# 544                                   Brugada syndrome     9
# 151                 GLUCOCORTICOID DEFICIENCY 2; GCCD2     3
# 91           SUCRASE-ISOMALTASE DEFICIENCY, CONGENITAL    12
# 323                         IMMUNODEFICIENCY 34; IMD34     3
# 510                              TYROSINEMIA, TYPE III     8
# 454                        HYPOPHOSPHATASIA, INFANTILE    15
# 564                   LYSOSOMAL ACID LIPASE DEFICIENCY     4
# 406        THROMBOPHILIA DUE TO THROMBIN DEFECT; THPH1     1
# 455                        HYPOPHOSPHATASIA, CHILDHOOD    17
# 528                                   Brugada syndrome     9
# 4    HEMOLYTIC UREMIC SYNDROME, ATYPICAL, SUSCEPTIB...     8
# 543     DIABETES MELLITUS, PERMANENT NEONATAL 2; PNDM2    12
# 515                                    SCHEIE SYNDROME    81
# 636            HYPERPHENYLALANINEMIA, BH4-DEFICIENT, D     2
# 198                BROWN-VIALETTO-VAN LAERE SYNDROME 1     4
# 180                      NIEMANN-PICK DISEASE, TYPE C2     8
# 670  IMMUNODEFICIENCY 26 WITH OR WITHOUT NEUROLOGIC...    65
# 423                  GLYCOGEN STORAGE DISEASE II; GSD2   100
# 117         MYASTHENIC SYNDROME, CONGENITAL, 18; CMS18     2
# 139            AUTOIMMUNE LYMPHOPROLIFERATIVE SYNDROME     5
# 374           Familial or sporadic hemiplegic migraine     2
# 125       MATURITY-ONSET DIABETES OF THE YOUNG, TYPE 3     5
# 238                         NEPHROTIC SYNDROME, TYPE 9     6
# 426                Congenital erythropoietic porphyria     3
# 569  METHYLMALONIC ACIDURIA AND HOMOCYSTINURIA, cbl...     2
